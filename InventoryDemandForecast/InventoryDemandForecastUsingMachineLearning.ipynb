# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import metrics
from sklearn.svm import SVC
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error as mae
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/StoreDemand.csv')
display(df.head())
display(df.tail())
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10
#               date  store  item  sales
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82

# %%
df.shape
# Out:
# (913000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  object
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 27.9+ MB

# %%
df.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %% [markdown]
# ## Feature Engineering

# %%
parts = df["date"].str.split("-", n = 3, expand = True)
df["year"] = parts[0].astype('int')
df["month"] = parts[1].astype('int')
df["day"] = parts[2].astype('int')
df.head
# Out:
# <bound method NDFrame.head of               date  store  item  sales  year  month  day
# 0       2013-01-01      1     1     13  2013      1    1
# 1       2013-01-02      1     1     11  2013      1    2
# 2       2013-01-03      1     1     14  2013      1    3
# 3       2013-01-04      1     1     13  2013      1    4
# 4       2013-01-05      1     1     10  2013      1    5
# ...            ...    ...   ...    ...   ...    ...  ...
# 912995  2017-12-27     10    50     63  2017     12   27
# 912996  2017-12-28     10    50     59  2017     12   28
# 912997  2017-12-29     10    50     74  2017     12   29
# 912998  2017-12-30     10    50     62  2017     12   30
# 912999  2017-12-31     10    50     82  2017     12   31
#
# [913000 rows x 7 columns]>

# %%
print(parts)
# Out:
#            0   1   2
# 0       2013  01  01
# 1       2013  01  02
# 2       2013  01  03
# 3       2013  01  04
# 4       2013  01  05
# ...      ...  ..  ..
# 912995  2017  12  27
# 912996  2017  12  28
# 912997  2017  12  29
# 912998  2017  12  30
# 912999  2017  12  31
#
# [913000 rows x 3 columns]

# %%
from datetime import datetime
import calendar

def weekend_or_weekday(year, month, day):
    d = datetime(year, month, day)
    if d.weekday() >= 5:
        return 1
    else: 
        return 0

df['weekend'] = df.apply(lambda x: weekend_or_weekday(x['year'], x['month'], x['day']), axis=1)
df.head()
# Out:
#          date  store  item  sales  year  month  day  weekend
# 0  2013-01-01      1     1     13  2013      1    1        0
# 1  2013-01-02      1     1     11  2013      1    2        0
# 2  2013-01-03      1     1     14  2013      1    3        0
# 3  2013-01-04      1     1     13  2013      1    4        0
# 4  2013-01-05      1     1     10  2013      1    5        1

# %%
from datetime import date
import holidays

def is_holiday(x):

    india_holidays = holidays.country_holidays('IN')

    if india_holidays.get(x):
        return 1
    else:
        return 0
df['holidays'] = df['date'].apply(is_holiday)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#      10     else:
#      11         return 0
# ---> 12 df['holidays'] = df['date'].apply(is_holiday)
#      13 df.head()
#
# File c:\Users\86176\tf\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\86176\tf\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\86176\tf\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\86176\tf\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\86176\tf\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[18], line 8, in is_holiday(x)
#       4 def is_holiday(x):
#       6     india_holidays = holidays.country_holidays('IN')
# ----> 8     if india_holidays.get(x):
#       9         return 1
#      10     else:
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\holiday_base.py:892, in HolidayBase.get(self, key, default)
#     873 def get(self, key: DateLike, default: Union[str, Any] = None) -> Union[str, Any]:
#     874     """Return the holiday name for a date if date is a holiday, else
#     875     default. If default is not given, it defaults to None, so that this
#     876     method never raises a KeyError. If more than one holiday is present,
#    (...)
#     890         The default value to return if no value is found.
#     891     """
# --> 892     return dict.get(self, self.__keytransform__(key), default)
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\holiday_base.py:616, in HolidayBase.__keytransform__(self, key)
#     614 if self.expand and dt.year not in self.years:
#     615     self.years.add(dt.year)
# --> 616     self._populate(dt.year)
#     618 return dt
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\holiday_base.py:832, in HolidayBase._populate(self, year)
#     815 """This is a private class that populates (generates and adds) holidays
#     816 for a given year. To keep things fast, it assumes that no holidays for
#     817 the year have already been populated. It is required to be called
#    (...)
#     828 >>> us_holidays.update(country_holidays('US', years=2021))
#     829 """
#     831 self._year = year
# --> 832 self._populate_common_holidays()
#     833 self._populate_subdiv_holidays()
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\holiday_base.py:839, in HolidayBase._populate_common_holidays(self)
#     837 for category in self._sorted_categories:
#     838     if pch_method := getattr(self, f"_populate_{category.lower()}_holidays", None):
# --> 839         pch_method()
#     841 if self.has_special_holidays:
#     842     self._add_special_holidays(
#     843         f"special_{category}_holidays" for category in self._sorted_categories
#     844     )
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\countries\india.py:181, in India._populate_public_holidays(self)
#     177     self._add_holiday("Holi", holi_dates[self._year])
#     179 # Islamic holidays.
#     180 # Day of Ashura.
# --> 181 self._add_ashura_day("Day of Ashura")
#     183 # Birth of the Prophet.
#     184 self._add_mawlid_day("Mawlid")
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\groups\islamic.py:92, in IslamicHolidays._add_ashura_day(self, name)
#      84 def _add_ashura_day(self, name) -> Set[date]:
#      85     """
#      86     Add Ashura Day (10th day of 1st month).
#      87
#    (...)
#      90     https://en.wikipedia.org/wiki/Ashura
#      91     """
# ---> 92     return self._add_islamic_calendar_holiday(
#      93         name, self._islamic_calendar.ashura_dates(self._year)
#      94     )
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\groups\islamic.py:264, in IslamicHolidays._add_islamic_calendar_holiday(self, name, dates, days_delta)
#     257 """
#     258 Add lunar calendar holiday.
#     259
#     260 Appends customizable estimation label at the end of holiday name if
#     261 holiday date is an estimation.
#     262 """
#     263 added_dates = set()
# --> 264 estimated_label = getattr(self, "estimated_label", "%s (estimated)")
#     265 for dt, is_estimated in dates:
#     266     if days_delta != 0:
#
# File c:\Users\86176\tf\Lib\site-packages\holidays\holiday_base.py:429, in HolidayBase.__getattr__(self, name)
#     425             return False
#     427     return dict.__eq__(cast("Dict[Any, Any]", self), other)
# --> 429 def __getattr__(self, name):
#     430     try:
#     431         return self.__getattribute__(name)
#
# KeyboardInterrupt:

# %%
df['m1'] = np
